# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import json
import shutil
import random
from pathlib import Path
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import requests
from tqdm import tqdm
from urllib.parse import urlparse
import numpy as np

# %%
from mtrain.smallnet.unet.extract import generate_dataset

TACO_DIR = Path("/Users/hariomnarang/Desktop/personal/TACO/data")
ANN_FILE = TACO_DIR / "annotations.json"

# PROJECT_CODE = os.environ["PROJECT_CODE"]
# DATA_COUNT = int(os.environ["DATA_COUNT"])
# TILE_SIZE = int(os.environ["TILE_SIZE"])
# BATCH_SIZE = int(os.environ.get("BATCH_SIZE", "16"))
# FINE_TUNE_EPOCHS = int(os.environ["FINE_TUNE_EPOCHS"])
# FIT_EPOCHS = int(os.environ.get("FIT_EPOCHS"))
# MODEL = os.environ.get("MODEL", "resnet18")

# PROJECT_DIR = DRIVE_BASE / "garbage" / "experiments" / PROJECT_CODE
# LOG_BASE = PROJECT_DIR / "log"
# DATA_DIR = Path(os.environ.get("WORKING_DATA_DIR", "/content/out"))

# PROJECT_DIR.mkdir(exist_ok=True, parents=True)
# LOG_BASE.mkdir(exist_ok=True, parents=True)

ROOT_CROPS = Path("../../datasets/taco-unet-crops/raw/")
ROOT_CROPS.mkdir(parents=True, exist_ok=True)

confs = [30, 40, 50, 60, 80, 100]
n = 3000
for c in confs:
    dest = ROOT_CROPS / f"size-{c}-num-{n}"
    generate_dataset(
        ann_file=ANN_FILE,
        taco_dir=TACO_DIR,
        output_path=dest,
        tile_size=c,
        num_samples=n,
        workers=16,
    )
# Out:
# CACHE MISS: triggering data generation
# CACHE MISS: triggering data generation
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# Starting image and mask extraction
# Progress track: EXTRACT; CHUNK=2 total_samples=94
# Progress track: EXTRACT; CHUNK=0 total_samples=94
# Progress track: EXTRACT; CHUNK=3 total_samples=94
# Progress track: EXTRACT; CHUNK=1 total_samples=94
# Progress track: EXTRACT; CHUNK=4 total_samples=94
# Progress track: EXTRACT; CHUNK=5 total_samples=94
# Progress track: EXTRACT; CHUNK=9 total_samples=94
# Progress track: EXTRACT; CHUNK=6 total_samples=94
# Progress track: EXTRACT; CHUNK=8 total_samples=94
# Progress track: EXTRACT; CHUNK=7 total_samples=94
# Progress track: EXTRACT; CHUNK=12 total_samples=93
# EXTRACT; CHUNK=4: 0%
# Progress track: EXTRACT; CHUNK=11 total_samples=93
# Progress track: EXTRACT; CHUNK=15 total_samples=93
# Progress track: EXTRACT; CHUNK=10 total_samples=93
# EXTRACT; CHUNK=0: 0%
# EXTRACT; CHUNK=3: 0%
# Progress track: EXTRACT; CHUNK=13 total_samples=93
# EXTRACT; CHUNK=9: 0%
# EXTRACT; CHUNK=2: 0%
# EXTRACT; CHUNK=8: 0%
# EXTRACT; CHUNK=1: 0%
# EXTRACT; CHUNK=6: 0%
# EXTRACT; CHUNK=5: 0%
# Progress track: EXTRACT; CHUNK=14 total_samples=93
# EXTRACT; CHUNK=12: 0%
# EXTRACT; CHUNK=11: 0%
# EXTRACT; CHUNK=15: 0%
# EXTRACT; CHUNK=13: 0%
# EXTRACT; CHUNK=7: 0%
# EXTRACT; CHUNK=8: 5%
# EXTRACT; CHUNK=14: 0%
# EXTRACT; CHUNK=10: 0%
# EXTRACT; CHUNK=1: 5%
# EXTRACT; CHUNK=0: 5%
# EXTRACT; CHUNK=9: 5%
# EXTRACT; CHUNK=3: 5%
# EXTRACT; CHUNK=12: 5%
# EXTRACT; CHUNK=15: 5%
# EXTRACT; CHUNK=11: 5%
# EXTRACT; CHUNK=6: 5%
# EXTRACT; CHUNK=2: 5%
# EXTRACT; CHUNK=13: 5%
# EXTRACT; CHUNK=14: 5%
# EXTRACT; CHUNK=5: 5%
# EXTRACT; CHUNK=10: 5%
# EXTRACT; CHUNK=6: 10%
# EXTRACT; CHUNK=1: 10%
# EXTRACT; CHUNK=2: 10%
# EXTRACT; CHUNK=9: 10%
# EXTRACT; CHUNK=11: 10%
# EXTRACT; CHUNK=0: 10%
# EXTRACT; CHUNK=8: 10%
# EXTRACT; CHUNK=4: 5%
# EXTRACT; CHUNK=15: 10%
# EXTRACT; CHUNK=7: 5%
# EXTRACT; CHUNK=3: 10%
# EXTRACT; CHUNK=12: 10%
# EXTRACT; CHUNK=14: 10%
# EXTRACT; CHUNK=13: 10%
# EXTRACT; CHUNK=0: 15%
# EXTRACT; CHUNK=6: 15%
# EXTRACT; CHUNK=2: 15%
# EXTRACT; CHUNK=9: 15%
# EXTRACT; CHUNK=1: 15%
# EXTRACT; CHUNK=11: 15%
# EXTRACT; CHUNK=15: 15%
# EXTRACT; CHUNK=5: 10%
# EXTRACT; CHUNK=8: 15%
# EXTRACT; CHUNK=10: 10%
# EXTRACT; CHUNK=3: 15%
# EXTRACT; CHUNK=13: 15%
# EXTRACT; CHUNK=12: 15%
# EXTRACT; CHUNK=14: 15%
# EXTRACT; CHUNK=7: 10%
# EXTRACT; CHUNK=1: 20%
# EXTRACT; CHUNK=0: 20%
# EXTRACT; CHUNK=2: 20%
# EXTRACT; CHUNK=4: 10%
# EXTRACT; CHUNK=6: 20%
# EXTRACT; CHUNK=11: 20%
# EXTRACT; CHUNK=10: 15%
# EXTRACT; CHUNK=9: 20%
# EXTRACT; CHUNK=15: 20%
# EXTRACT; CHUNK=13: 20%
# EXTRACT; CHUNK=3: 20%
# EXTRACT; CHUNK=8: 20%
# EXTRACT; CHUNK=7: 15%
# EXTRACT; CHUNK=2: 25%
# EXTRACT; CHUNK=0: 25%
# EXTRACT; CHUNK=12: 20%
# EXTRACT; CHUNK=14: 20%
# EXTRACT; CHUNK=4: 15%
# EXTRACT; CHUNK=5: 15%
# EXTRACT; CHUNK=9: 25%
# EXTRACT; CHUNK=15: 25%
# EXTRACT; CHUNK=10: 20%
# EXTRACT; CHUNK=11: 25%
# EXTRACT; CHUNK=8: 25%
# EXTRACT; CHUNK=1: 25%
# EXTRACT; CHUNK=3: 25%
# EXTRACT; CHUNK=7: 20%
# EXTRACT; CHUNK=13: 25%
# EXTRACT; CHUNK=5: 20%
# EXTRACT; CHUNK=15: 30%
# EXTRACT; CHUNK=0: 30%
# EXTRACT; CHUNK=12: 25%
# EXTRACT; CHUNK=6: 25%
# EXTRACT; CHUNK=11: 30%
# EXTRACT; CHUNK=2: 30%
# EXTRACT; CHUNK=9: 30%
# EXTRACT; CHUNK=13: 30%
# EXTRACT; CHUNK=0: 35%
# EXTRACT; CHUNK=8: 30%
# EXTRACT; CHUNK=4: 20%
# EXTRACT; CHUNK=14: 25%
# EXTRACT; CHUNK=10: 25%
# EXTRACT; CHUNK=3: 30%
# EXTRACT; CHUNK=7: 25%
# EXTRACT; CHUNK=9: 35%
# EXTRACT; CHUNK=2: 35%
# EXTRACT; CHUNK=5: 25%
# EXTRACT; CHUNK=11: 35%
# EXTRACT; CHUNK=6: 30%
# EXTRACT; CHUNK=0: 40%
# EXTRACT; CHUNK=12: 30%
# EXTRACT; CHUNK=4: 25%
# EXTRACT; CHUNK=14: 30%
# EXTRACT; CHUNK=1: 30%
# EXTRACT; CHUNK=8: 35%
# EXTRACT; CHUNK=3: 35%
# EXTRACT; CHUNK=7: 30%
# EXTRACT; CHUNK=15: 35%
# EXTRACT; CHUNK=10: 30%
# EXTRACT; CHUNK=13: 35%
# EXTRACT; CHUNK=6: 35%
# EXTRACT; CHUNK=11: 40%
# EXTRACT; CHUNK=2: 40%
# EXTRACT; CHUNK=14: 35%
# EXTRACT; CHUNK=9: 40%
# EXTRACT; CHUNK=12: 35%
# EXTRACT; CHUNK=7: 35%
# EXTRACT; CHUNK=1: 35%
# EXTRACT; CHUNK=0: 45%
# EXTRACT; CHUNK=15: 40%
# EXTRACT; CHUNK=11: 45%
# EXTRACT; CHUNK=8: 40%
# EXTRACT; CHUNK=13: 40%
# EXTRACT; CHUNK=5: 30%
# EXTRACT; CHUNK=6: 40%
# EXTRACT; CHUNK=2: 45%
# EXTRACT; CHUNK=3: 40%
# EXTRACT; CHUNK=10: 35%
# EXTRACT; CHUNK=9: 45%
# EXTRACT; CHUNK=4: 30%
# EXTRACT; CHUNK=15: 45%
# EXTRACT; CHUNK=14: 40%
# EXTRACT; CHUNK=7: 40%
# EXTRACT; CHUNK=11: 50%
# EXTRACT; CHUNK=6: 45%
# EXTRACT; CHUNK=12: 40%
# EXTRACT; CHUNK=5: 35%
# EXTRACT; CHUNK=13: 45%
# EXTRACT; CHUNK=0: 50%
# EXTRACT; CHUNK=14: 45%
# EXTRACT; CHUNK=10: 40%
# EXTRACT; CHUNK=1: 40%
# EXTRACT; CHUNK=8: 45%
# EXTRACT; CHUNK=2: 50%
# EXTRACT; CHUNK=3: 45%
# EXTRACT; CHUNK=4: 35%
# EXTRACT; CHUNK=12: 45%
# EXTRACT; CHUNK=15: 50%
# EXTRACT; CHUNK=7: 45%
# EXTRACT; CHUNK=0: 55%
# EXTRACT; CHUNK=13: 50%
# EXTRACT; CHUNK=11: 55%
# EXTRACT; CHUNK=6: 50%
# EXTRACT; CHUNK=9: 50%
# EXTRACT; CHUNK=3: 50%
# EXTRACT; CHUNK=10: 45%
# EXTRACT; CHUNK=14: 50%
# EXTRACT; CHUNK=5: 40%
# EXTRACT; CHUNK=2: 55%
# EXTRACT; CHUNK=1: 45%
# EXTRACT; CHUNK=8: 50%
# EXTRACT; CHUNK=12: 50%
# EXTRACT; CHUNK=4: 40%
# EXTRACT; CHUNK=11: 60%
# EXTRACT; CHUNK=14: 55%
# EXTRACT; CHUNK=9: 55%
# EXTRACT; CHUNK=13: 55%
# EXTRACT; CHUNK=1: 50%
# EXTRACT; CHUNK=5: 45%
# EXTRACT; CHUNK=0: 60%
# EXTRACT; CHUNK=2: 60%
# EXTRACT; CHUNK=3: 55%
# EXTRACT; CHUNK=6: 55%
# EXTRACT; CHUNK=7: 50%
# EXTRACT; CHUNK=4: 45%
# EXTRACT; CHUNK=15: 55%
# EXTRACT; CHUNK=14: 60%
# EXTRACT; CHUNK=12: 55%
# EXTRACT; CHUNK=10: 50%
# EXTRACT; CHUNK=8: 55%
# EXTRACT; CHUNK=1: 55%
# EXTRACT; CHUNK=0: 65%
# EXTRACT; CHUNK=13: 60%
# EXTRACT; CHUNK=11: 65%
# EXTRACT; CHUNK=15: 60%
# EXTRACT; CHUNK=3: 60%
# EXTRACT; CHUNK=12: 60%
# EXTRACT; CHUNK=5: 50%
# EXTRACT; CHUNK=2: 65%
# EXTRACT; CHUNK=0: 70%
# EXTRACT; CHUNK=4: 50%
# EXTRACT; CHUNK=7: 55%
# EXTRACT; CHUNK=6: 60%
# EXTRACT; CHUNK=10: 55%
# EXTRACT; CHUNK=11: 70%
# EXTRACT; CHUNK=15: 65%
# EXTRACT; CHUNK=8: 60%
# EXTRACT; CHUNK=13: 65%
# EXTRACT; CHUNK=5: 55%
# EXTRACT; CHUNK=2: 70%
# EXTRACT; CHUNK=1: 60%
# EXTRACT; CHUNK=14: 65%
# EXTRACT; CHUNK=4: 55%
# EXTRACT; CHUNK=3: 65%
# EXTRACT; CHUNK=9: 60%
# EXTRACT; CHUNK=6: 65%
# EXTRACT; CHUNK=12: 65%
# EXTRACT; CHUNK=0: 75%
# EXTRACT; CHUNK=7: 60%
# EXTRACT; CHUNK=11: 75%
# EXTRACT; CHUNK=5: 60%
# EXTRACT; CHUNK=15: 70%
# EXTRACT; CHUNK=10: 60%
# EXTRACT; CHUNK=2: 75%
# EXTRACT; CHUNK=4: 60%
# EXTRACT; CHUNK=13: 70%
# EXTRACT; CHUNK=12: 70%
# EXTRACT; CHUNK=7: 65%
# EXTRACT; CHUNK=14: 70%
# EXTRACT; CHUNK=3: 70%
# EXTRACT; CHUNK=8: 65%
# EXTRACT; CHUNK=6: 70%
# EXTRACT; CHUNK=1: 65%
# EXTRACT; CHUNK=12: 75%
# EXTRACT; CHUNK=9: 65%
# EXTRACT; CHUNK=15: 75%
# EXTRACT; CHUNK=5: 65%
# EXTRACT; CHUNK=11: 80%
# EXTRACT; CHUNK=7: 70%
# EXTRACT; CHUNK=0: 80%
# EXTRACT; CHUNK=10: 65%
# EXTRACT; CHUNK=14: 75%
# EXTRACT; CHUNK=4: 65%
# EXTRACT; CHUNK=8: 70%
# EXTRACT; CHUNK=13: 75%
# EXTRACT; CHUNK=5: 70%
# EXTRACT; CHUNK=3: 75%
# EXTRACT; CHUNK=1: 70%
# EXTRACT; CHUNK=6: 75%
# EXTRACT; CHUNK=0: 85%
# EXTRACT; CHUNK=9: 70%
# EXTRACT; CHUNK=10: 70%
# EXTRACT; CHUNK=11: 85%
# EXTRACT; CHUNK=7: 75%
# EXTRACT; CHUNK=2: 80%
# EXTRACT; CHUNK=4: 70%
# EXTRACT; CHUNK=8: 75%
# EXTRACT; CHUNK=12: 80%
# EXTRACT; CHUNK=15: 80%
# EXTRACT; CHUNK=14: 80%
# EXTRACT; CHUNK=13: 80%
# EXTRACT; CHUNK=2: 85%
# EXTRACT; CHUNK=10: 75%
# EXTRACT; CHUNK=3: 80%
# EXTRACT; CHUNK=1: 75%
# EXTRACT; CHUNK=6: 80%
# EXTRACT; CHUNK=11: 90%
# EXTRACT; CHUNK=5: 75%
# EXTRACT; CHUNK=9: 75%
# EXTRACT; CHUNK=7: 80%
# EXTRACT; CHUNK=8: 80%
# EXTRACT; CHUNK=4: 75%
# EXTRACT; CHUNK=0: 90%
# EXTRACT; CHUNK=10: 80%
# EXTRACT; CHUNK=14: 85%
# EXTRACT; CHUNK=15: 85%
# EXTRACT; CHUNK=2: 90%
# EXTRACT; CHUNK=6: 85%
# EXTRACT; CHUNK=12: 85%
# EXTRACT; CHUNK=3: 85%
# EXTRACT; CHUNK=1: 80%
# EXTRACT; CHUNK=5: 80%
# EXTRACT; CHUNK=7: 85%
# EXTRACT; CHUNK=8: 85%
# EXTRACT; CHUNK=2: 95%
# EXTRACT; CHUNK=11: 95%
# EXTRACT; CHUNK=3: 90%
# EXTRACT; CHUNK=13: 85%
# EXTRACT; CHUNK=10: 85%
# EXTRACT; CHUNK=9: 80%
# EXTRACT; CHUNK=14: 90%
# EXTRACT; CHUNK=0: 95%
# EXTRACT; CHUNK=6: 90%
# EXTRACT; CHUNK=15: 90%
# EXTRACT; CHUNK=4: 80%
# EXTRACT; CHUNK=1: 85%
# EXTRACT; CHUNK=10: 90%
# EXTRACT; CHUNK=11: 100%
# EXTRACT; CHUNK=5: 85%
# EXTRACT; CHUNK=9: 85%
# EXTRACT; CHUNK=2: 100%
# EXTRACT; CHUNK=7: 90%
# EXTRACT; CHUNK=12: 90%
# EXTRACT; CHUNK=0: 100%
# EXTRACT; CHUNK=8: 90%
# EXTRACT; CHUNK=15: 95%
# EXTRACT; CHUNK=13: 90%
# EXTRACT; CHUNK=4: 85%
# EXTRACT; CHUNK=6: 95%
# EXTRACT; CHUNK=1: 90%
# EXTRACT; CHUNK=14: 95%
# EXTRACT; CHUNK=10: 95%
# EXTRACT; CHUNK=3: 95%
# EXTRACT; CHUNK=12: 95%
# EXTRACT; CHUNK=9: 90%
# EXTRACT; CHUNK=8: 95%
# EXTRACT; CHUNK=7: 95%
# EXTRACT; CHUNK=14: 100%
# EXTRACT; CHUNK=6: 100%
# EXTRACT; CHUNK=4: 90%
# EXTRACT; CHUNK=15: 100%
# EXTRACT; CHUNK=5: 90%
# EXTRACT; CHUNK=1: 95%
# EXTRACT; CHUNK=10: 100%
# EXTRACT; CHUNK=3: 100%
# EXTRACT; CHUNK=13: 95%
# EXTRACT; CHUNK=9: 95%
# EXTRACT; CHUNK=12: 100%
# EXTRACT; CHUNK=7: 100%
# EXTRACT; CHUNK=8: 100%
# EXTRACT; CHUNK=5: 95%
# EXTRACT; CHUNK=4: 95%
# EXTRACT; CHUNK=1: 100%
# EXTRACT; CHUNK=9: 100%
# EXTRACT; CHUNK=13: 100%
# EXTRACT; CHUNK=5: 100%
# EXTRACT; CHUNK=4: 100%
# Copy: /Users/hariomnarang/.mtrain_synth_cache/extract_images_and_masks_21c3fc8885a49223 /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/multi-level
# copied files: 2997 to /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/multi-level
# extraction: done
# starting binary collapse of dataset, input=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/multi-level output=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level
# Original codes: ['background', 'Aluminium foil', 'Battery', 'Aluminium blister pack', 'Carded blister pack', 'Other plastic bottle', 'Clear plastic bottle', 'Glass bottle', 'Plastic bottle cap', 'Metal bottle cap', 'Broken glass', 'Food Can', 'Aerosol', 'Drink can', 'Toilet tube', 'Other carton', 'Egg carton', 'Drink carton', 'Corrugated carton', 'Meal carton', 'Pizza box', 'Paper cup', 'Disposable plastic cup', 'Foam cup', 'Glass cup', 'Other plastic cup', 'Food waste', 'Glass jar', 'Plastic lid', 'Metal lid', 'Other plastic', 'Magazine paper', 'Tissues', 'Wrapping paper', 'Normal paper', 'Paper bag', 'Plastic film', 'Six pack rings', 'Garbage bag', 'Other plastic wrapper', 'Single-use carrier bag', 'Polypropylene bag', 'Crisp packet', 'Spread tub', 'Tupperware', 'Disposable food container', 'Foam food container', 'Other plastic container', 'Plastic glooves', 'Plastic utensils', 'Pop tab', 'Rope & strings', 'Scrap metal', 'Shoe', 'Squeezable tube', 'Plastic straw', 'Paper straw', 'Styrofoam piece', 'Unlabeled litter', 'Cigarette']
# Progress track: CVT MASK:  total_samples=1498
# Progress track: CVT MASK: 11 total_samples=93
# CVT MASK: 11: 10%
# Progress track: CVT MASK: 0 total_samples=94
# CVT MASK: 0: 0%
# Progress track: CVT MASK: 2 total_samples=94
# CVT MASK: 2: 0%
# Progress track: CVT MASK: 12 total_samples=93
# CVT MASK: 12: 10%
# Progress track: CVT MASK: 9 total_samples=94
# CVT MASK: 9: 10%
# Progress track: CVT MASK: 5 total_samples=94
# CVT MASK: 5: 5%
# Progress track: CVT MASK: 6 total_samples=94
# CVT MASK: 6: 5%
# Progress track: CVT MASK: 1 total_samples=94
# CVT MASK: 1: 0%
# Progress track: CVT MASK: 8 total_samples=94
# CVT MASK: 8: 5%
# Progress track: CVT MASK: 14 total_samples=93
# CVT MASK: 14: 15%
# Progress track: CVT MASK: 13 total_samples=93
# CVT MASK: 13: 15%
# Progress track: CVT MASK: 10 total_samples=93
# CVT MASK: 10: 10%
# Progress track: CVT MASK: 15 total_samples=93
# CVT MASK: 15: 15%
# Progress track: CVT MASK: 3 total_samples=94
# CVT MASK: 3: 0%
# Progress track: CVT MASK: 7 total_samples=94
# CVT MASK: 7: 5%
# Progress track: CVT MASK: 4 total_samples=94
# CVT MASK: 4: 5%
# Progress track: COPY_IMAGE total_samples=1498
# COPY_IMAGE: 0%
# COPY_IMAGE: 10%
# COPY_IMAGE: 20%
# COPY_IMAGE: 30%
# COPY_IMAGE: 40%
# COPY_IMAGE: 50%
# COPY_IMAGE: 60%
# COPY_IMAGE: 70%
# COPY_IMAGE: 80%
# COPY_IMAGE: 90%
# COPY_IMAGE: 100%
# Binary dataset created at: /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level
# binary collapse: done
# output directory exists at /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_744e2593dfb18e2b, nuking
# CACHE MISS: triggering data generation
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# CROPS: output directory /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_7e673eb3f91b6ca9 exists, nuking
# Creating 3000 crops from 1498 images
# Progress track: MPCrop 3: total_samples=750
# Progress track: MPCrop 1: total_samples=750
# Progress track: MPCrop 0: total_samples=750
# Progress track: MPCrop 2: total_samples=750
# MPCrop 1:: 0%
# MPCrop 3:: 0%
# MPCrop 0:: 0%
# MPCrop 2:: 0%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level/images/326.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level/images/327.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 10%
# MPCrop 3:: 10%
# MPCrop 0:: 10%
# MPCrop 2:: 10%
# MPCrop 1:: 20%
# MPCrop 0:: 20%
# MPCrop 2:: 20%
# MPCrop 3:: 20%
# MPCrop 1:: 30%
# MPCrop 3:: 30%
# MPCrop 0:: 30%
# MPCrop 2:: 30%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level/images/231.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level/images/333.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level/images/334.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 40%
# MPCrop 3:: 40%
# MPCrop 0:: 40%
# MPCrop 2:: 40%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level/images/342.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 50%
# MPCrop 0:: 50%
# MPCrop 2:: 50%
# MPCrop 3:: 50%
# MPCrop 2:: 60%
# MPCrop 1:: 60%
# MPCrop 0:: 60%
# MPCrop 3:: 60%
# MPCrop 0:: 70%
# MPCrop 2:: 70%
# MPCrop 1:: 70%
# MPCrop 3:: 70%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level/images/551.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level/images/551.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 80%
# MPCrop 2:: 80%
# MPCrop 1:: 80%
# MPCrop 3:: 80%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level/images/310.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level/images/310.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmppvzmr__1/binary-level/images/324.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 2:: 90%
# MPCrop 0:: 90%
# MPCrop 1:: 90%
# MPCrop 3:: 90%
# MPCrop 2:: 100%
# MPCrop 0:: 100%
# MPCrop 1:: 100%
# MPCrop 3:: 100%
# Copy: /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_7e673eb3f91b6ca9 /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_744e2593dfb18e2b
# copied files: 2992 to /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_744e2593dfb18e2b
# crops: done
# Copy: /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_744e2593dfb18e2b ../../datasets/taco-unet-crops/raw/size-30-num-3000
# copied files: 2992 to ../../datasets/taco-unet-crops/raw/size-30-num-3000
# CACHE MISS: triggering data generation
# CACHE HIT: will copy to /Users/hariomnarang/.mtrain_synth_cache/extract_images_and_masks_21c3fc8885a49223 -> /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/multi-level
# Copy: /Users/hariomnarang/.mtrain_synth_cache/extract_images_and_masks_21c3fc8885a49223 /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/multi-level
# copied files: 2997 to /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/multi-level
# extraction: done
# starting binary collapse of dataset, input=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/multi-level output=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level
# Original codes: ['background', 'Aluminium foil', 'Battery', 'Aluminium blister pack', 'Carded blister pack', 'Other plastic bottle', 'Clear plastic bottle', 'Glass bottle', 'Plastic bottle cap', 'Metal bottle cap', 'Broken glass', 'Food Can', 'Aerosol', 'Drink can', 'Toilet tube', 'Other carton', 'Egg carton', 'Drink carton', 'Corrugated carton', 'Meal carton', 'Pizza box', 'Paper cup', 'Disposable plastic cup', 'Foam cup', 'Glass cup', 'Other plastic cup', 'Food waste', 'Glass jar', 'Plastic lid', 'Metal lid', 'Other plastic', 'Magazine paper', 'Tissues', 'Wrapping paper', 'Normal paper', 'Paper bag', 'Plastic film', 'Six pack rings', 'Garbage bag', 'Other plastic wrapper', 'Single-use carrier bag', 'Polypropylene bag', 'Crisp packet', 'Spread tub', 'Tupperware', 'Disposable food container', 'Foam food container', 'Other plastic container', 'Plastic glooves', 'Plastic utensils', 'Pop tab', 'Rope & strings', 'Scrap metal', 'Shoe', 'Squeezable tube', 'Plastic straw', 'Paper straw', 'Styrofoam piece', 'Unlabeled litter', 'Cigarette']
# Progress track: CVT MASK:  total_samples=1498
# Progress track: CVT MASK: 7 total_samples=94
# CVT MASK: 7: 5%
# Progress track: CVT MASK: 3 total_samples=94
# CVT MASK: 3: 0%
# Progress track: CVT MASK: 0 total_samples=94
# CVT MASK: 0: 0%
# Progress track: CVT MASK: 8 total_samples=94
# CVT MASK: 8: 5%
# Progress track: CVT MASK: 11 total_samples=93
# CVT MASK: 11: 10%
# Progress track: CVT MASK: 4 total_samples=94
# CVT MASK: 4: 5%
# Progress track: CVT MASK: 2 total_samples=94
# CVT MASK: 2: 0%
# Progress track: CVT MASK: 1 total_samples=94
# CVT MASK: 1: 0%
# Progress track: CVT MASK: 15 total_samples=93
# CVT MASK: 15: 15%
# Progress track: CVT MASK: 14 total_samples=93
# CVT MASK: 14: 15%
# Progress track: CVT MASK: 5 total_samples=94
# CVT MASK: 5: 5%
# Progress track: CVT MASK: 12 total_samples=93
# CVT MASK: 12: 10%
# Progress track: CVT MASK: 6 total_samples=94
# CVT MASK: 6: 5%
# Progress track: CVT MASK: 9 total_samples=94
# CVT MASK: 9: 10%
# Progress track: CVT MASK: 10 total_samples=93
# CVT MASK: 10: 10%
# Progress track: CVT MASK: 13 total_samples=93
# CVT MASK: 13: 15%
# Progress track: COPY_IMAGE total_samples=1498
# COPY_IMAGE: 0%
# COPY_IMAGE: 10%
# COPY_IMAGE: 20%
# COPY_IMAGE: 30%
# COPY_IMAGE: 40%
# COPY_IMAGE: 50%
# COPY_IMAGE: 60%
# COPY_IMAGE: 70%
# COPY_IMAGE: 80%
# COPY_IMAGE: 90%
# COPY_IMAGE: 100%
# Binary dataset created at: /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level
# binary collapse: done
# output directory exists at /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_5f03512cec2d5696, nuking
# CACHE MISS: triggering data generation
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# CROPS: output directory /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_ce61e846dcd86e65 exists, nuking
# Creating 3000 crops from 1498 images
# Progress track: MPCrop 0: total_samples=750
# Progress track: MPCrop 2: total_samples=750
# Progress track: MPCrop 3: total_samples=750
# Progress track: MPCrop 1: total_samples=750
# MPCrop 1:: 0%
# MPCrop 3:: 0%
# MPCrop 0:: 0%
# MPCrop 2:: 0%
# MPCrop 0:: 10%
# MPCrop 2:: 10%
# MPCrop 1:: 10%
# MPCrop 3:: 10%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/298.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/326.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/324.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/600.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 20%
# MPCrop 2:: 20%
# MPCrop 1:: 20%
# MPCrop 3:: 20%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/318.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 30%
# MPCrop 2:: 30%
# MPCrop 1:: 30%
# MPCrop 3:: 30%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/332.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 2:: 40%
# MPCrop 0:: 40%
# MPCrop 1:: 40%
# MPCrop 3:: 40%
# MPCrop 2:: 50%
# MPCrop 0:: 50%
# MPCrop 1:: 50%
# MPCrop 3:: 50%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/322.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 2:: 60%
# MPCrop 0:: 60%
# MPCrop 1:: 60%
# MPCrop 3:: 60%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/297.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/328.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'
# . ignoring
# MPCrop 2:: 70%
# MPCrop 0:: 70%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/336.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 70%
# MPCrop 3:: 70%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/296.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 2:: 80%
# MPCrop 0:: 80%
# MPCrop 1:: 80%
# MPCrop 3:: 80%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/329.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 2:: 90%
# MPCrop 0:: 90%
# MPCrop 1:: 90%
# MPCrop 3:: 90%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp4qgc5oy8/binary-level/images/334.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 2:: 100%
# MPCrop 0:: 100%
# MPCrop 1:: 100%
# MPCrop 3:: 100%
# Copy: /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_ce61e846dcd86e65 /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_5f03512cec2d5696
# copied files: 2996 to /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_5f03512cec2d5696
# crops: done
# Copy: /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_5f03512cec2d5696 ../../datasets/taco-unet-crops/raw/size-40-num-3000
# copied files: 2996 to ../../datasets/taco-unet-crops/raw/size-40-num-3000
# CACHE MISS: triggering data generation
# CACHE HIT: will copy to /Users/hariomnarang/.mtrain_synth_cache/extract_images_and_masks_21c3fc8885a49223 -> /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/multi-level
# Copy: /Users/hariomnarang/.mtrain_synth_cache/extract_images_and_masks_21c3fc8885a49223 /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/multi-level
# copied files: 2997 to /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/multi-level
# extraction: done
# starting binary collapse of dataset, input=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/multi-level output=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level
# Original codes: ['background', 'Aluminium foil', 'Battery', 'Aluminium blister pack', 'Carded blister pack', 'Other plastic bottle', 'Clear plastic bottle', 'Glass bottle', 'Plastic bottle cap', 'Metal bottle cap', 'Broken glass', 'Food Can', 'Aerosol', 'Drink can', 'Toilet tube', 'Other carton', 'Egg carton', 'Drink carton', 'Corrugated carton', 'Meal carton', 'Pizza box', 'Paper cup', 'Disposable plastic cup', 'Foam cup', 'Glass cup', 'Other plastic cup', 'Food waste', 'Glass jar', 'Plastic lid', 'Metal lid', 'Other plastic', 'Magazine paper', 'Tissues', 'Wrapping paper', 'Normal paper', 'Paper bag', 'Plastic film', 'Six pack rings', 'Garbage bag', 'Other plastic wrapper', 'Single-use carrier bag', 'Polypropylene bag', 'Crisp packet', 'Spread tub', 'Tupperware', 'Disposable food container', 'Foam food container', 'Other plastic container', 'Plastic glooves', 'Plastic utensils', 'Pop tab', 'Rope & strings', 'Scrap metal', 'Shoe', 'Squeezable tube', 'Plastic straw', 'Paper straw', 'Styrofoam piece', 'Unlabeled litter', 'Cigarette']
# Progress track: CVT MASK:  total_samples=1498
# Progress track: CVT MASK: 8 total_samples=94
# CVT MASK: 8: 5%
# Progress track: CVT MASK: 3 total_samples=94
# CVT MASK: 3: 0%
# Progress track: CVT MASK: 10 total_samples=93
# CVT MASK: 10: 10%
# Progress track: CVT MASK: 4 total_samples=94
# CVT MASK: 4: 5%
# Progress track: CVT MASK: 11 total_samples=93
# CVT MASK: 11: 10%
# Progress track: CVT MASK: 5 total_samples=94
# CVT MASK: 5: 5%
# Progress track: CVT MASK: 7 total_samples=94
# CVT MASK: 7: 5%
# Progress track: CVT MASK: 15 total_samples=93
# CVT MASK: 15: 15%
# Progress track: CVT MASK: 13 total_samples=93
# CVT MASK: 13: 15%
# Progress track: CVT MASK: 2 total_samples=94
# CVT MASK: 2: 0%
# Progress track: CVT MASK: 0 total_samples=94
# CVT MASK: 0: 0%
# Progress track: CVT MASK: 9 total_samples=94
# CVT MASK: 9: 10%
# Progress track: CVT MASK: 14 total_samples=93
# CVT MASK: 14: 15%
# Progress track: CVT MASK: 1 total_samples=94
# CVT MASK: 1: 0%
# Progress track: CVT MASK: 6 total_samples=94
# CVT MASK: 6: 5%
# Progress track: CVT MASK: 12 total_samples=93
# CVT MASK: 12: 10%
# Progress track: COPY_IMAGE total_samples=1498
# COPY_IMAGE: 0%
# COPY_IMAGE: 10%
# COPY_IMAGE: 20%
# COPY_IMAGE: 30%
# COPY_IMAGE: 40%
# COPY_IMAGE: 50%
# COPY_IMAGE: 60%
# COPY_IMAGE: 70%
# COPY_IMAGE: 80%
# COPY_IMAGE: 90%
# COPY_IMAGE: 100%
# Binary dataset created at: /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level
# binary collapse: done
# output directory exists at /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_707677987c22ab2f, nuking
# CACHE MISS: triggering data generation
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# CROPS: output directory /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_da51b4e00323f0a8 exists, nuking
# Creating 3000 crops from 1498 images
# Progress track: MPCrop 0: total_samples=750
# Progress track: MPCrop 1: total_samples=750
# Progress track: MPCrop 3: total_samples=750
# Progress track: MPCrop 2: total_samples=750
# MPCrop 0:: 0%
# MPCrop 1:: 0%
# MPCrop 2:: 0%
# MPCrop 3:: 0%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/334.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/611.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 10%
# MPCrop 2:: 10%
# MPCrop 3:: 10%
# MPCrop 1:: 10%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/333.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/333.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 20%
# MPCrop 2:: 20%
# MPCrop 1:: 20%
# MPCrop 3:: 20%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/572.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/572.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/614.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 30%
# MPCrop 2:: 30%
# MPCrop 1:: 30%
# MPCrop 3:: 30%
# MPCrop 0:: 40%
# MPCrop 2:: 40%
# MPCrop 1:: 40%
# MPCrop 3:: 40%
# MPCrop 0:: 50%
# MPCrop 2:: 50%
# MPCrop 1:: 50%
# MPCrop 3:: 50%
# MPCrop 0:: 60%
# MPCrop 2:: 60%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/336.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 60%
# MPCrop 3:: 60%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/324.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 70%
# MPCrop 2:: 70%
# MPCrop 1:: 70%
# MPCrop 3:: 70%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/231.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 80%
# MPCrop 2:: 80%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/310.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 80%
# MPCrop 3:: 80%
# MPCrop 0:: 90%
# MPCrop 2:: 90%
# MPCrop 1:: 90%
# MPCrop 3:: 90%
# MPCrop 0:: 100%
# MPCrop 2:: 100%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmp8mdsna2d/binary-level/images/597.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 100%
# MPCrop 3:: 100%
# Copy: /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_da51b4e00323f0a8 /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_707677987c22ab2f
# copied files: 2992 to /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_707677987c22ab2f
# crops: done
# Copy: /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_707677987c22ab2f ../../datasets/taco-unet-crops/raw/size-50-num-3000
# copied files: 2992 to ../../datasets/taco-unet-crops/raw/size-50-num-3000
# CACHE MISS: triggering data generation
# CACHE HIT: will copy to /Users/hariomnarang/.mtrain_synth_cache/extract_images_and_masks_21c3fc8885a49223 -> /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/multi-level
# Copy: /Users/hariomnarang/.mtrain_synth_cache/extract_images_and_masks_21c3fc8885a49223 /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/multi-level
# copied files: 2997 to /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/multi-level
# extraction: done
# starting binary collapse of dataset, input=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/multi-level output=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level
# Original codes: ['background', 'Aluminium foil', 'Battery', 'Aluminium blister pack', 'Carded blister pack', 'Other plastic bottle', 'Clear plastic bottle', 'Glass bottle', 'Plastic bottle cap', 'Metal bottle cap', 'Broken glass', 'Food Can', 'Aerosol', 'Drink can', 'Toilet tube', 'Other carton', 'Egg carton', 'Drink carton', 'Corrugated carton', 'Meal carton', 'Pizza box', 'Paper cup', 'Disposable plastic cup', 'Foam cup', 'Glass cup', 'Other plastic cup', 'Food waste', 'Glass jar', 'Plastic lid', 'Metal lid', 'Other plastic', 'Magazine paper', 'Tissues', 'Wrapping paper', 'Normal paper', 'Paper bag', 'Plastic film', 'Six pack rings', 'Garbage bag', 'Other plastic wrapper', 'Single-use carrier bag', 'Polypropylene bag', 'Crisp packet', 'Spread tub', 'Tupperware', 'Disposable food container', 'Foam food container', 'Other plastic container', 'Plastic glooves', 'Plastic utensils', 'Pop tab', 'Rope & strings', 'Scrap metal', 'Shoe', 'Squeezable tube', 'Plastic straw', 'Paper straw', 'Styrofoam piece', 'Unlabeled litter', 'Cigarette']
# Progress track: CVT MASK:  total_samples=1498
# Progress track: CVT MASK: 10 total_samples=93
# CVT MASK: 10: 10%
# Progress track: CVT MASK: 8 total_samples=94
# CVT MASK: 8: 5%
# Progress track: CVT MASK: 6 total_samples=94
# CVT MASK: 6: 5%
# Progress track: CVT MASK: 5 total_samples=94
# CVT MASK: 5: 5%
# Progress track: CVT MASK: 3 total_samples=94
# CVT MASK: 3: 0%
# Progress track: CVT MASK: 0 total_samples=94
# CVT MASK: 0: 0%
# Progress track: CVT MASK: 11 total_samples=93
# CVT MASK: 11: 10%
# Progress track: CVT MASK: 1 total_samples=94
# CVT MASK: 1: 0%
# Progress track: CVT MASK: 7 total_samples=94
# CVT MASK: 7: 5%
# Progress track: CVT MASK: 2 total_samples=94
# CVT MASK: 2: 0%
# Progress track: CVT MASK: 9 total_samples=94
# CVT MASK: 9: 10%
# Progress track: CVT MASK: 4 total_samples=94
# CVT MASK: 4: 5%
# Progress track: CVT MASK: 12 total_samples=93
# CVT MASK: 12: 10%
# Progress track: CVT MASK: 14 total_samples=93
# CVT MASK: 14: 15%
# Progress track: CVT MASK: 15 total_samples=93
# CVT MASK: 15: 15%
# Progress track: CVT MASK: 13 total_samples=93
# CVT MASK: 13: 15%
# Progress track: COPY_IMAGE total_samples=1498
# COPY_IMAGE: 0%
# COPY_IMAGE: 10%
# COPY_IMAGE: 20%
# COPY_IMAGE: 30%
# COPY_IMAGE: 40%
# COPY_IMAGE: 50%
# COPY_IMAGE: 60%
# COPY_IMAGE: 70%
# COPY_IMAGE: 80%
# COPY_IMAGE: 90%
# COPY_IMAGE: 100%
# Binary dataset created at: /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level
# binary collapse: done
# output directory exists at /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_4368f786f12adf15, nuking
# CACHE MISS: triggering data generation
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# CROPS: output directory /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_2ebc611374e9c203 exists, nuking
# Creating 3000 crops from 1498 images
# Progress track: MPCrop 1: total_samples=750
# Progress track: MPCrop 0: total_samples=750
# Progress track: MPCrop 2: total_samples=750
# Progress track: MPCrop 3: total_samples=750
# MPCrop 3:: 0%
# MPCrop 0:: 0%
# MPCrop 2:: 0%
# MPCrop 1:: 0%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level/images/334.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 10%
# MPCrop 3:: 10%
# MPCrop 0:: 10%
# MPCrop 2:: 10%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level/images/324.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level/images/331.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 20%
# MPCrop 3:: 20%
# MPCrop 0:: 20%
# MPCrop 2:: 20%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level/images/332.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 30%
# MPCrop 3:: 30%
# MPCrop 0:: 30%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level/images/342.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 2:: 30%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level/images/342.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 3:: 40%
# MPCrop 1:: 40%
# MPCrop 0:: 40%
# MPCrop 2:: 40%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level/images/328.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 50%
# MPCrop 3:: 50%
# MPCrop 0:: 50%
# MPCrop 2:: 50%
# MPCrop 1:: 60%
# MPCrop 3:: 60%
# MPCrop 0:: 60%
# MPCrop 2:: 60%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level/images/298.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 70%
# MPCrop 3:: 70%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level/images/551.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 70%
# MPCrop 2:: 70%
# MPCrop 1:: 80%
# MPCrop 3:: 80%
# MPCrop 0:: 80%
# MPCrop 2:: 80%
# MPCrop 1:: 90%
# MPCrop 3:: 90%
# MPCrop 0:: 90%
# MPCrop 2:: 90%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpq7z5m9ig/binary-level/images/329.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 100%
# MPCrop 3:: 100%
# MPCrop 0:: 100%
# MPCrop 2:: 100%
# Copy: /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_2ebc611374e9c203 /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_4368f786f12adf15
# copied files: 2994 to /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_4368f786f12adf15
# crops: done
# Copy: /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_4368f786f12adf15 ../../datasets/taco-unet-crops/raw/size-60-num-3000
# copied files: 2994 to ../../datasets/taco-unet-crops/raw/size-60-num-3000
# CACHE MISS: triggering data generation
# CACHE HIT: will copy to /Users/hariomnarang/.mtrain_synth_cache/extract_images_and_masks_21c3fc8885a49223 -> /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/multi-level
# Copy: /Users/hariomnarang/.mtrain_synth_cache/extract_images_and_masks_21c3fc8885a49223 /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/multi-level
# copied files: 2997 to /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/multi-level
# extraction: done
# starting binary collapse of dataset, input=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/multi-level output=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level
# Original codes: ['background', 'Aluminium foil', 'Battery', 'Aluminium blister pack', 'Carded blister pack', 'Other plastic bottle', 'Clear plastic bottle', 'Glass bottle', 'Plastic bottle cap', 'Metal bottle cap', 'Broken glass', 'Food Can', 'Aerosol', 'Drink can', 'Toilet tube', 'Other carton', 'Egg carton', 'Drink carton', 'Corrugated carton', 'Meal carton', 'Pizza box', 'Paper cup', 'Disposable plastic cup', 'Foam cup', 'Glass cup', 'Other plastic cup', 'Food waste', 'Glass jar', 'Plastic lid', 'Metal lid', 'Other plastic', 'Magazine paper', 'Tissues', 'Wrapping paper', 'Normal paper', 'Paper bag', 'Plastic film', 'Six pack rings', 'Garbage bag', 'Other plastic wrapper', 'Single-use carrier bag', 'Polypropylene bag', 'Crisp packet', 'Spread tub', 'Tupperware', 'Disposable food container', 'Foam food container', 'Other plastic container', 'Plastic glooves', 'Plastic utensils', 'Pop tab', 'Rope & strings', 'Scrap metal', 'Shoe', 'Squeezable tube', 'Plastic straw', 'Paper straw', 'Styrofoam piece', 'Unlabeled litter', 'Cigarette']
# Progress track: CVT MASK:  total_samples=1498
# Progress track: CVT MASK: 1 total_samples=94
# CVT MASK: 1: 0%
# Progress track: CVT MASK: 2 total_samples=94
# CVT MASK: 2: 0%
# Progress track: CVT MASK: 11 total_samples=93
# CVT MASK: 11: 10%
# Progress track: CVT MASK: 3 total_samples=94
# CVT MASK: 3: 0%
# Progress track: CVT MASK: 13 total_samples=93
# CVT MASK: 13: 15%
# Progress track: CVT MASK: 8 total_samples=94
# CVT MASK: 8: 5%
# Progress track: CVT MASK: 12 total_samples=93
# CVT MASK: 12: 10%
# Progress track: CVT MASK: 5 total_samples=94
# CVT MASK: 5: 5%
# Progress track: CVT MASK: 9 total_samples=94
# CVT MASK: 9: 10%
# Progress track: CVT MASK: 6 total_samples=94
# CVT MASK: 6: 5%
# Progress track: CVT MASK: 0 total_samples=94
# CVT MASK: 0: 0%
# Progress track: CVT MASK: 14 total_samples=93
# CVT MASK: 14: 15%
# Progress track: CVT MASK: 7 total_samples=94
# CVT MASK: 7: 5%
# Progress track: CVT MASK: 4 total_samples=94
# CVT MASK: 4: 5%
# Progress track: CVT MASK: 10 total_samples=93
# CVT MASK: 10: 10%
# Progress track: CVT MASK: 15 total_samples=93
# CVT MASK: 15: 15%
# Progress track: COPY_IMAGE total_samples=1498
# COPY_IMAGE: 0%
# COPY_IMAGE: 10%
# COPY_IMAGE: 20%
# COPY_IMAGE: 30%
# COPY_IMAGE: 40%
# COPY_IMAGE: 50%
# COPY_IMAGE: 60%
# COPY_IMAGE: 70%
# COPY_IMAGE: 80%
# COPY_IMAGE: 90%
# COPY_IMAGE: 100%
# Binary dataset created at: /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level
# binary collapse: done
# output directory exists at /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_7f9fd62718800552, nuking
# CACHE MISS: triggering data generation
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# CROPS: output directory /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_085d547d12375195 exists, nuking
# Creating 3000 crops from 1498 images
# Progress track: MPCrop 0: total_samples=750
# Progress track: MPCrop 3: total_samples=750
# Progress track: MPCrop 1: total_samples=750
# Progress track: MPCrop 2: total_samples=750
# MPCrop 0:: 0%
# MPCrop 3:: 0%
# MPCrop 1:: 0%
# MPCrop 2:: 0%
# MPCrop 0:: 10%
# MPCrop 2:: 10%
# MPCrop 3:: 10%
# MPCrop 1:: 10%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/572.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4211: error: (-215:Assertion failed) inv_scale_x > 0 in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/296.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/328.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# ...
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/334.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/334.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 40%
# MPCrop 2:: 40%
# MPCrop 1:: 40%
# MPCrop 3:: 40%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/329.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 50%
# MPCrop 2:: 50%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/333.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/333.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 50%
# MPCrop 3:: 50%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/327.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 60%
# MPCrop 2:: 60%
# MPCrop 1:: 60%
# MPCrop 3:: 60%
# MPCrop 0:: 70%
# MPCrop 2:: 70%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/298.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 70%
# MPCrop 3:: 70%
# MPCrop 0:: 80%
# MPCrop 2:: 80%
# MPCrop 1:: 80%
# MPCrop 3:: 80%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/332.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/332.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 90%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/301.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 2:: 90%
# MPCrop 1:: 90%
# MPCrop 3:: 90%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/342.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpd51igp51/binary-level/images/342.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 100%
# MPCrop 2:: 100%
# MPCrop 1:: 100%
# MPCrop 3:: 100%
# Copy: /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_085d547d12375195 /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_7f9fd62718800552
# copied files: 2988 to /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_7f9fd62718800552
# crops: done
# Copy: /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_7f9fd62718800552 ../../datasets/taco-unet-crops/raw/size-80-num-3000
# copied files: 2988 to ../../datasets/taco-unet-crops/raw/size-80-num-3000
# CACHE MISS: triggering data generation
# CACHE HIT: will copy to /Users/hariomnarang/.mtrain_synth_cache/extract_images_and_masks_21c3fc8885a49223 -> /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/multi-level
# Copy: /Users/hariomnarang/.mtrain_synth_cache/extract_images_and_masks_21c3fc8885a49223 /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/multi-level
# copied files: 2997 to /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/multi-level
# extraction: done
# starting binary collapse of dataset, input=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/multi-level output=/var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level
# Original codes: ['background', 'Aluminium foil', 'Battery', 'Aluminium blister pack', 'Carded blister pack', 'Other plastic bottle', 'Clear plastic bottle', 'Glass bottle', 'Plastic bottle cap', 'Metal bottle cap', 'Broken glass', 'Food Can', 'Aerosol', 'Drink can', 'Toilet tube', 'Other carton', 'Egg carton', 'Drink carton', 'Corrugated carton', 'Meal carton', 'Pizza box', 'Paper cup', 'Disposable plastic cup', 'Foam cup', 'Glass cup', 'Other plastic cup', 'Food waste', 'Glass jar', 'Plastic lid', 'Metal lid', 'Other plastic', 'Magazine paper', 'Tissues', 'Wrapping paper', 'Normal paper', 'Paper bag', 'Plastic film', 'Six pack rings', 'Garbage bag', 'Other plastic wrapper', 'Single-use carrier bag', 'Polypropylene bag', 'Crisp packet', 'Spread tub', 'Tupperware', 'Disposable food container', 'Foam food container', 'Other plastic container', 'Plastic glooves', 'Plastic utensils', 'Pop tab', 'Rope & strings', 'Scrap metal', 'Shoe', 'Squeezable tube', 'Plastic straw', 'Paper straw', 'Styrofoam piece', 'Unlabeled litter', 'Cigarette']
# Progress track: CVT MASK:  total_samples=1498
# Progress track: CVT MASK: 5 total_samples=94
# CVT MASK: 5: 5%
# Progress track: CVT MASK: 0 total_samples=94
# CVT MASK: 0: 0%
# Progress track: CVT MASK: 4 total_samples=94
# CVT MASK: 4: 5%
# Progress track: CVT MASK: 7 total_samples=94
# CVT MASK: 7: 5%
# Progress track: CVT MASK: 2 total_samples=94
# CVT MASK: 2: 0%
# Progress track: CVT MASK: 6 total_samples=94
# CVT MASK: 6: 5%
# Progress track: CVT MASK: 1 total_samples=94
# CVT MASK: 1: 0%
# Progress track: CVT MASK: 3 total_samples=94
# CVT MASK: 3: 0%
# Progress track: CVT MASK: 14 total_samples=93
# CVT MASK: 14: 15%
# Progress track: CVT MASK: 8 total_samples=94
# CVT MASK: 8: 5%
# Progress track: CVT MASK: 10 total_samples=93
# CVT MASK: 10: 10%
# Progress track: CVT MASK: 9 total_samples=94
# CVT MASK: 9: 10%
# Progress track: CVT MASK: 13 total_samples=93
# CVT MASK: 13: 15%
# Progress track: CVT MASK: 15 total_samples=93
# CVT MASK: 15: 15%
# Progress track: CVT MASK: 12 total_samples=93
# CVT MASK: 12: 10%
# Progress track: CVT MASK: 11 total_samples=93
# CVT MASK: 11: 10%
# Progress track: COPY_IMAGE total_samples=1498
# COPY_IMAGE: 0%
# COPY_IMAGE: 10%
# COPY_IMAGE: 20%
# COPY_IMAGE: 30%
# COPY_IMAGE: 40%
# COPY_IMAGE: 50%
# COPY_IMAGE: 60%
# COPY_IMAGE: 70%
# COPY_IMAGE: 80%
# COPY_IMAGE: 90%
# COPY_IMAGE: 100%
# Binary dataset created at: /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level
# binary collapse: done
# output directory exists at /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_221904bd8a146ec6, nuking
# CACHE MISS: triggering data generation
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# CROPS: output directory /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_a8ebca89e618df4e exists, nuking
# Creating 3000 crops from 1498 images
# Progress track: MPCrop 1: total_samples=750
# Progress track: MPCrop 2: total_samples=750
# Progress track: MPCrop 3: total_samples=750
# Progress track: MPCrop 0: total_samples=750
# MPCrop 3:: 0%
# MPCrop 0:: 0%
# MPCrop 2:: 0%
# MPCrop 1:: 0%
# MPCrop 1:: 10%
# MPCrop 3:: 10%
# MPCrop 2:: 10%
# MPCrop 0:: 10%
# MPCrop 1:: 20%
# MPCrop 2:: 20%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/551.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 3:: 20%
# MPCrop 0:: 20%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/310.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/310.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/326.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/326.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/324.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/298.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/324.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/297.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 30%
# MPCrop 3:: 30%
# MPCrop 2:: 30%
# MPCrop 0:: 30%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/231.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 40%
# MPCrop 3:: 40%
# MPCrop 2:: 40%
# MPCrop 0:: 40%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/334.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 50%
# MPCrop 3:: 50%
# MPCrop 2:: 50%
# MPCrop 0:: 50%
# MPCrop 1:: 60%
# MPCrop 3:: 60%
# MPCrop 2:: 60%
# MPCrop 0:: 60%
# MPCrop 1:: 70%
# MPCrop 3:: 70%
# MPCrop 2:: 70%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/362.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 0:: 70%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/342.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/333.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/333.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 3:: 80%
# MPCrop 1:: 80%
# MPCrop 2:: 80%
# MPCrop 0:: 80%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/336.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 90%
# MPCrop 3:: 90%
# MPCrop 2:: 90%
# MPCrop 0:: 90%
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/331.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# failure in generating crop for /var/folders/sn/p2_4kq491_d66c474d1ms9jm0000gn/T/tmpt7vbj5u8/binary-level/images/330.jpeg, reason=OpenCV(4.13.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# . ignoring
# MPCrop 1:: 100%
# MPCrop 3:: 100%
# MPCrop 0:: 100%
# MPCrop 2:: 100%
# Copy: /Users/hariomnarang/.mtrain_synth_cache/create_crops_from_extracted_a8ebca89e618df4e /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_221904bd8a146ec6
# copied files: 2988 to /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_221904bd8a146ec6
# crops: done
# Copy: /Users/hariomnarang/.mtrain_synth_cache/generate_dataset_221904bd8a146ec6 ../../datasets/taco-unet-crops/raw/size-100-num-3000
# copied files: 2988 to ../../datasets/taco-unet-crops/raw/size-100-num-3000
