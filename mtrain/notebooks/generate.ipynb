# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import cv2
import random

SAMPLES_BASE = Path("/Users/hariomnarang/Desktop/personal/roads/datasets/clean_samples")

CROPS_BASE = Path("/Users/hariomnarang/Desktop/personal/roads/datasets/crops/v3")

SAMPLES_BASE.exists(), CROPS_BASE.exists()
# Out:
# (True, True)

# %%
from mtrain.synth.gen import generate_data

# %%
generate_data(SAMPLES_BASE, CROPS_BASE, Path("./test_synth"), 100)
# Out:
# 5050it [00:00, 5786.06it/s]

# %%
from ultralytics import YOLO
INITIAL_MODEL = 'yolov8n.pt'
model = YOLO(INITIAL_MODEL)

# %%
from mtrain.yolo.split import prepare_yolo_dataset

prepare_yolo_dataset(Path("./test_synth/images"), Path("./test_synth/labels"), Path("./test_final_synth"), "0")
# Out:
# Total images: 100
# Train: 80 (80.0%)
# Val: 10 (10.0%)
# Test: 10 (10.0%)
#
# Processing train set...
#
# Processing val set...
#
# Processing test set...
# Nothing missing. Total labels prepared = 100
#
# Dataset split completed! Output directory: test_final_synth
# Updated data.yaml at: /Users/hariomnarang/Desktop/personal/roads/mtrain/notebooks/test_final_synth/data.yaml
