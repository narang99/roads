# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mtrain.synth.v3 import generate
from mtrain.data_prep.prep_crops import PrepareCrops
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import cv2
import random

# %%
DATASETS = Path("../../datasets/")
EXPR_DIR = DATASETS / "T003-extract-and-place-on-backdrops-manually" 
CROP_OUT_DIR = EXPR_DIR / "crops"
IMAGES = ["/Users/hariomnarang/Desktop/personal/roads/datasets/T003-extract-and-place-on-backdrops-manually/images/14325/image.jpg"]
EXPORT_FILE = "/Users/hariomnarang/Desktop/personal/roads/datasets/T003-extract-and-place-on-backdrops-manually/full_export.json"

IMAGES = [
    "/Users/hariomnarang/Desktop/personal/roads/datasets/T003-extract-and-place-on-backdrops-manually/backdrops/1.jpeg",
    "/Users/hariomnarang/Desktop/personal/roads/datasets/T003-extract-and-place-on-backdrops-manually/backdrops/3.jpeg",
]

# %%
pcrps = PrepareCrops(CROP_OUT_DIR)
crops = [
    crp for crp in pcrps.get_all_existing_crops() if crp.proc
]

# %%
plt.imshow(generate(IMAGES[0], crops))
plt.show()
# Out:
# {'scale': np.float64(3.0), 'blur': 0, 'luminosity': -1}
# {'scale': np.float64(0.6126126126126126), 'blur': 1, 'luminosity': -1}
# params StdLumMatcherParams(src_mean=np.float32(92.71795), src_std=np.float32(70.02128), tgt_mean=np.float32(103.60659), tgt_std=np.float32(21.82647))
# {'scale': np.float64(0.1), 'blur': 2, 'luminosity': 1.312439974602922}
# params StdLumMatcherParams(src_mean=np.float32(94.823616), src_std=np.float32(82.42396), tgt_mean=np.float32(244.41473), tgt_std=np.float32(11.537338))
# {'scale': np.float64(0.1), 'blur': 1, 'luminosity': 1.4209512353181368}
# params StdLumMatcherParams(src_mean=np.float32(99.00513), src_std=np.float32(46.548626), tgt_mean=np.float32(116.42672), tgt_std=np.float32(5.0793934))
# {'scale': np.float64(3.0), 'blur': 0, 'luminosity': 1.055766779119654}
# params StdLumMatcherParams(src_mean=np.float32(102.11047), src_std=np.float32(64.127335), tgt_mean=np.float32(172.98141), tgt_std=np.float32(15.803366))
# {'scale': np.float64(0.23829787234042557), 'blur': 0, 'luminosity': 1.1768816052016025}
