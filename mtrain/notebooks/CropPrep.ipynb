# %%
# %load_ext autoreload
# %autoreload 2

# %%
# main notebook to crop out fragments of garbage from a given image
# the focus is on minimal changes in this notebook. 
# this would be a script, but we have the problem of manually checking 
# what label to use in kmeans, so we have a notebook right now

from mtrain.data_prep.prep_crops import PrepareCrops
from mtrain.data_prep.prep_img import PrepareImages
from pathlib import Path

DATASETS = Path("../../datasets/")
DATASETS.exists()

### generally, only changing the variables here should be good
### change stuff here
EXPR_DIR = DATASETS / "T003-extract-and-place-on-backdrops-manually" 
OUT_DIR = EXPR_DIR / "crops"
IMAGES = ["/Users/hariomnarang/Desktop/personal/roads/datasets/T003-extract-and-place-on-backdrops-manually/images/14325/image.jpg"]
EXPORT_FILE = "/Users/hariomnarang/Desktop/personal/roads/datasets/T003-extract-and-place-on-backdrops-manually/full_export.json"

# %%
prep = PrepareImages(EXPR_DIR / "images")
prep.add_raw_all(EXPORT_FILE)
# Out:
# [PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/images/14314'),
#  PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/images/14321'),
#  PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/images/14325'),
#  PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/images/14326'),
#  PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/images/14327'),
#  PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/images/14338'),
#  PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/images/14345'),
#  PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/images/14363'),
#  PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/images/14366'),
#  PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/images/14382'),
#  PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/images/14388'),
# ...

# %%
# from mtrain.seg.cityscapes import get_cached_seg_former, CityScapesCls
# import matplotlib.pyplot as plt

# model = get_cached_seg_former()
# pred = model.predict("/Users/hariomnarang/Desktop/personal/roads/mapillary_downloader/data/samples/kanpur/images/1144359109397377.jpg")
# road_mask = model.get_mask(pred, CityScapesCls.ROAD)
# _, ax = plt.subplots(1, 2)
# ax[0].imshow(road_mask)
# ax[1].imshow(plt.imread("/Users/hariomnarang/Desktop/personal/roads/mapillary_downloader/data/samples/kanpur/images/1144359109397377.jpg"))
# # return _calculate_horizon_road_edges(img, road_mask)

# %%
pr_crps = PrepareCrops(OUT_DIR)

# %%
pr_crps.dump_raw_all(EXPORT_FILE)

# %%
explorer = pr_crps.get_kmeans_explorer(
    "/Users/hariomnarang/Desktop/personal/roads/datasets/T003-extract-and-place-on-backdrops-manually/backdrops/3.jpeg",
    10
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Desktop/personal/roads/mtrain/.venv/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File ~/Desktop/personal/roads/mtrain/.venv/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# ...

# %%
from mtrain import luminosity

luminosity.get_std_matcher_params(explorer.original_img_bgr, explorer.backdrop_bgr)
# Out:
# StdLumMatcherParams(src_mean=np.float32(132.76326), src_std=np.float32(47.001274), tgt_mean=np.float32(144.0118), tgt_std=np.float32(61.611618))

# %%
luminosity.get_std_matcher_params(explorer.orig_crop_bgr, explorer.backdrop_bgr)
# Out:
# StdLumMatcherParams(src_mean=np.float32(64.3354), src_std=np.float32(29.09358), tgt_mean=np.float32(144.0118), tgt_std=np.float32(61.611618))

# %%
_ = explorer.display()
