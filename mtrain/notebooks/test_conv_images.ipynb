# %% [markdown]
# # Create test set to find convolution
#
# We empirically find a convolution now. Need a test set. Will use the ones suggested by AI, and add some more on top of them.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import cv2
import random

# %%
# set this to get images of this size
SIZE = 50

# %%
def S(img):
    if img.shape[0] == 1:
        img = img[0]
    plt.imshow(img, cmap="gray")
    plt.show()

# %%
from mtrain.interp.cds import *

# %%
S(black(SIZE))

# %%
S(single_line(SIZE, 160))

# %%
S(unit_impulse(SIZE))

# %%
S(step_edge(SIZE))

# %%
S(linear_gradient(SIZE, 90))

# %%
S(checkerboard(50))

# %%
S(filled_circle(50))

# %%
S(stripes(50, 45))

# %%
S(concentric_circles(50))

# %%
S(random_noise(50))

# %%
white(SIZE)
