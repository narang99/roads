# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = "/Users/hariomnarang/Desktop/personal/roads/datasets/flowers"
medium = plt.imread(f"{f}/inat/photos/342423839_0.jpg")
# large = plt.imread(f"{f}/large.jpg")
# small = plt.imread(f"{f}/small.jpg")
# square = plt.imread(f"{f}/square.jpg")

# %%
print(medium.shape)
plt.imshow(medium)

# %%
medium.shape, large.shape, small.shape, square.shape

# %%
plt.imshow(medium)

# %%
plt.imshow(small)

# %%
plt.imshow(large)

# %%
kernel = np.array([[-7.3082857e-03, -3.3403710e-03, -1.7467763e-04,  7.6757632e-02,
         5.7633832e-02,  1.6015776e-02, -1.4074022e-02],
       [ 1.2547463e-02,  1.1612699e-02, -1.0910337e-01, -2.7929038e-01,
        -2.7108991e-01, -1.3092566e-01,  2.3329773e-03],
       [-6.6333138e-03,  5.9885956e-02,  2.9514366e-01,  5.8676970e-01,
         5.1820976e-01,  2.5462961e-01,  6.3829571e-02],
       [ 3.0143386e-02, -6.7846239e-02, -2.9862598e-01, -4.3761677e-01,
        -2.7047393e-01, -1.9195214e-03,  5.6869078e-02],
       [-2.7379388e-02,  1.5669614e-02,  7.2694339e-02, -5.3339396e-02,
        -3.3177319e-01, -4.2084736e-01, -2.5818154e-01],
       [ 3.1379919e-02,  4.1335262e-02,  6.2583819e-02,  2.3978779e-01,
         4.1502821e-01,  3.9319730e-01,  1.6546285e-01],
       [-1.3121805e-02, -4.0879184e-03, -2.4672065e-02, -6.3728094e-02,
        -1.4791882e-01, -8.0639988e-02, -4.6384558e-03]])
plt.imshow(kernel, cmap="gray")
