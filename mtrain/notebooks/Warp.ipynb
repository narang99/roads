# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from mtrain.synth.v3 import generate
from mtrain.data_prep.prep_crops import PrepareCrops
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import cv2
import random

# %%
DATASETS = Path("../../datasets/")
EXPR_DIR = DATASETS / "T003-extract-and-place-on-backdrops-manually" 
CROP_OUT_DIR = EXPR_DIR / "crops"
IMAGES = ["/Users/hariomnarang/Desktop/personal/roads/datasets/T003-extract-and-place-on-backdrops-manually/images/14325/image.jpg"]
EXPORT_FILE = "/Users/hariomnarang/Desktop/personal/roads/datasets/T003-extract-and-place-on-backdrops-manually/full_export.json"

IMAGES = [
    "/Users/hariomnarang/Desktop/personal/roads/datasets/T003-extract-and-place-on-backdrops-manually/backdrops/1.jpeg",
    "/Users/hariomnarang/Desktop/personal/roads/datasets/T003-extract-and-place-on-backdrops-manually/backdrops/3.jpeg",
]

# %%
pcrps = PrepareCrops(CROP_OUT_DIR)
crops = [
    crp for crp in pcrps.get_all_existing_crops() if crp.proc
]

# %%
def _pcvt(img_bgr):
    return cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# %%
from mtrain.color import random_color_shift
from mtrain.distort import random_warp

def random_change(img):
    img = random_warp(img)
    img = random_color_shift(img)
    return img

# %%
idx = 0

# %%
crops[idx]
# Out:
# SingleCrop(raw=PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/crops/61/raw.png'), proc=PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/crops/61/proc.png'), meta=PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/crops/61/meta.json'), mask=PosixPath('../../datasets/T003-extract-and-place-on-backdrops-manually/crops/61/mask.json'))

# %%
plt.imshow(_pcvt(random_change(cv2.imread(crops[idx].proc))))

# %%
idx += 1
